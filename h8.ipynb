# %%
class Cylinder:
    def __init__(self,r,h):
        self.r=r
        self.h=h
    def thetich(self):
        return (self.r**2)*3.14*self.h
    def dientich(self):
        return 2*(self.r**2)*3.14+2*self.r*3.14*self.h
bankinh=float(input())
chieucao=float(input())
xylanh=Cylinder(bankinh,chieucao)
print(xylanh.dientich())
print(xylanh.thetich())
# Out:
# 12.56
# 3.14

# %%
class Point:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def distance(self):
        ans=(self.x**2+self.y**2)**1/2
        return f'{ans:.2f}'
    def check(self):
        if self.x==0 and self.y==0:
            return 'goc toa do'
        elif self.y==0:
            return 'truc tung'
        elif self.x==0:
            return 'truc hoanh'
a,b=map(float,input().split())
point=Point(a,b)
print(point.distance())
print(point.check())
# Out:
# 1.00
# None

# %%
class Calculator:
    def __init__(self,num1,num2):
        self.num1=num1
        self.num2=num2
    def plus(self):
        return self.num1+self.num2
    def minus(self):
        return self.num1-self.num2
    def divide(self):
        return self.num1//self.num2
    def time(self):
        return self.num1*self.num2
    def du(self):
        return self.num1%self.num2
def calculator():
    a,b=map(float,input().split())
    phantu=Calculator(a,b)
    order=int(input('1: cong 2:tru 3:chia 4:nhan 5:du 6:nhapsomoi 0:thoat'))
    while order!=0:
        if order==1:
            return (phantu.plus())
        elif order==2:
            return (phantu.minus())
        elif order==3:
            return phantu.divide()
        elif order==4:
            return phantu.time()
        elif order==5:
            return phantu.du()
        

calculator()
# Out:
# 3.0

# %%
class Calculator:
    def __init__(self, a, b):
        """Khởi tạo với 2 số a và b"""
        self.a = a
        self.b = b

    def add(self):
        """1. Cộng"""
        return self.a + self.b

    def subtract(self):
        """2. Trừ"""
        return self.a - self.b

    def product(self):
        """3. Nhân"""
        return self.a * self.b

    def divide(self):
        """4. Chia"""
        if self.b == 0:
            return "Lỗi: Không thể chia cho 0"
        return self.a / self.b

    def power(self):
        """5. Lũy thừa (Mũ)"""
        return self.a ** self.b

    def mod(self):
        """6. Chia lấy phần dư"""
        if self.b == 0:
            return "Lỗi: Không thể chia cho 0"
        return self.a % self.b

    def set_numbers(self, a, b):
        """7. Cập nhật 2 số mới"""
        self.a = a
        self.b = b
        print(f"Đã cập nhật số thành công: {self.a} và {self.b}")


def main():
    print("CHƯƠNG TRÌNH MÁY TÍNH BỎ TÚI")
    
    try:
        num1 = float(input("Nhập số thứ nhất: "))
        num2 = float(input("Nhập số thứ hai: "))
    except ValueError:
        print("Vui lòng nhập số hợp lệ.")
        return

    
    calc = Calculator(num1, num2)

    while True:
        print("\n--- MENU ---")
        print(f"Hai số hiện tại: {calc.a} và {calc.b}")
        print("1. Cộng (add)")
        print("2. Trừ (subtract)")
        print("3. Nhân (product)")
        print("4. Chia (divide)")
        print("5. Lũy thừa (power)")
        print("6. Chia lấy dư (mod)")
        print("7. Nhập cặp số mới (set_numbers)")
        
        choice = input("Chọn chức năng (1-7): ")

        result = None

        if choice == '1':
            result = calc.add()
            print(f"Kết quả cộng: {result}")
        elif choice == '2':
            result = calc.subtract()
            print(f"Kết quả trừ: {result}")
        elif choice == '3':
            result = calc.product()
            print(f"Kết quả nhân: {result}")
        elif choice == '4':
            result = calc.divide()
            print(f"Kết quả chia: {result}")
        elif choice == '5':
            result = calc.power()
            print(f"Kết quả lũy thừa: {result}")
        elif choice == '6':
            result = calc.mod()
            print(f"Kết quả chia dư: {result}")
        elif choice == '7':
            try:
                n1 = float(input("Nhập số mới thứ nhất: "))
                n2 = float(input("Nhập số mới thứ hai: "))
                calc.set_numbers(n1, n2)
            except ValueError:
                print("Lỗi: Vui lòng nhập số hợp lệ.")
        else:
            print("Lựa chọn không hợp lệ, vui lòng chọn lại.")

        
        check_exit = input("\nBạn có muốn thoát? ")
        if check_exit in ["yes", "YES", "Yes"]:
            print("Đã thoát chương trình.")
            break

if __name__ == "__main__":
    main()
# Out:
# CHƯƠNG TRÌNH MÁY TÍNH BỎ TÚI
#
# --- MENU ---
# Hai số hiện tại: 1.0 và 2.0
# 1. Cộng (add)
# 2. Trừ (subtract)
# 3. Nhân (product)
# 4. Chia (divide)
# 5. Lũy thừa (power)
# 6. Chia lấy dư (mod)
# 7. Nhập cặp số mới (set_numbers)
# Đã cập nhật số thành công: 3.0 và 4.0
#
# --- MENU ---
# Hai số hiện tại: 3.0 và 4.0
# 1. Cộng (add)
# 2. Trừ (subtract)
# 3. Nhân (product)
# 4. Chia (divide)
# 5. Lũy thừa (power)
# 6. Chia lấy dư (mod)
# 7. Nhập cặp số mới (set_numbers)
# Kết quả nhân: 12.0
#
# --- MENU ---
# Hai số hiện tại: 3.0 và 4.0
# 1. Cộng (add)
# 2. Trừ (subtract)
# 3. Nhân (product)
# 4. Chia (divide)
# 5. Lũy thừa (power)
# 6. Chia lấy dư (mod)
# 7. Nhập cặp số mới (set_numbers)
# Kết quả cộng: 7.0
#
# --- MENU ---
# Hai số hiện tại: 3.0 và 4.0
# 1. Cộng (add)
# 2. Trừ (subtract)
# 3. Nhân (product)
# 4. Chia (divide)
# 5. Lũy thừa (power)
# 6. Chia lấy dư (mod)
# 7. Nhập cặp số mới (set_numbers)
# Đã cập nhật số thành công: 1.0 và 2.0
#
# --- MENU ---
# ...

# %%
class Rectangle:
    def __init__(self,height,width):
        self.height=height
        self.width=width
    def area(self):
        return 'dien tich la:', self.height*self.width
    def perimeter(self):
        return 'chu vi la:', 2*(self.height+self.width)
    def scale(self):
        k=float(input())
        self.height=self.height*k
        self.width=self.width*k
a,b=map(float,input().split())
hinh1=Rectangle(a,b)
print(hinh1.scale())
print(hinh1.area())
# Out:
# None
# ('dien tich la:', 4.0)

# %%
class Triangle:
    def __init__(self,edge1,edge2,edge3):
        self.edge1=edge1
        self.edge2=edge2
        self.edge3=edge3
    def check(self):
        if self.edge1 + self.edge2<=self.edge3:
            return False
        elif self.edge2 + self.edge3<=self.edge1:
            return False
        elif self.edge1+self.edge3<=self.edge2:
            return False
        return True
    def area(self):
        p=(self.edge1+self.edge2+self.edge3)/2
        ans=(p*(p-self.edge1)*(p-self.edge2)*(p-self.edge3))**0.5
        return ans
a,b,c=map(int,input().split())
tam1=Triangle(a,b,c)
if tam1.check():
    dien=tam1.area()
    print(f'{dien:.2f}')
else:
    print('Invalid')
# Out:
# 9.92
